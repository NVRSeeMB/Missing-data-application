# %%
import pandas as pd

# %%
data_import = pd.read_csv('test_data.csv')
data_import
# Out:
#           Date  Ordered Product Sales  Units Ordered  Total Order Items  \
# 0   2020-01-03                 229.95              0                  0
# 1   2020-01-15                   0.00              0                  0
# 2   2020-01-17                   0.00              0                  0
# 3   2020-01-19                   0.00              0                  0
# 4   2020-01-25                   0.00              0                  0
# ..         ...                    ...            ...                ...
# 86  2020-03-31                 214.77              8                  5
# 87  2020-03-24                 244.79             10                  5
# 88  2020-03-12                 449.87             13                  3
# 89  2020-03-19                 449.65             15                  8
# 90  2020-03-13                 727.69             19                  7
#
#     Average Sales per Order Item  Average Units per Order Item  \
# ...
